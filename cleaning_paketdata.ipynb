# %% [markdown]
# **Import Library**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Upload** **File**

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-896ac211-6def-49c6-9b4f-7cafc8b786cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-896ac211-6def-49c6-9b4f-7cafc8b786cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Mengolah data ke Dataframe atau Pandas**

# %%
# df_data = pd.read_csv('paketdata_mentah (1).csv')
df_data = pd.read_csv("paketdata_mentah.csv", encoding = 'unicode_escape')
df_data.head(10)
# Out:
#    No   Operator                                    Name  \
# 0   1         XL            Xtra Hotrod Special 2GB, 7hr
# 1   2         XL            Xtra Hotrod Special 3GB, 7hr
# 2   3       Axis                BRONET Mini 1.5GB 7 hari
# 3   4  Telkomsel          Telkomsel Data Flash 1GB, 30Hr
# 4   5       Axis                  BRONET Mini 2GB 7 hari
# 5   6         XL          Xtra Hotrod Special 4.5GB, 7hr
# 6   7       Axis               AIGO Bronet Mini 3GB 15hr
# 7   8       Axis  Paket Internet Axis BRONET 2GB 60 Hari
# 8   9       Axis                  BRONET Mini 5GB 7 hari
# 9  10       Axis                  BRONET Mini 8GB 7 hari
#
#                                          Description  Normal Price  Price  \
# 0  Kuota Utama 500MB + Kuota Area hingga 3.5GB + ...         12000  11200
# 1  Kuota Utama 1GB + Kuota Area hingga 6GB + YouT...         15000  14000
# 2  Kuota Internet 1.5GB berlaku di semua Jaringan...         14850  13973
# ...

# %%
df_data['Name'] = df_data['Name'].str.lower()
df_data['Description'] = df_data['Description'].str.lower()
df_data['Operator'] = df_data['Operator'].str.lower()

# %%
df_data.head(5)
# Out:
#    No   Operator                            Name  \
# 0   1         xl    xtra hotrod special 2gb, 7hr
# 1   2         xl    xtra hotrod special 3gb, 7hr
# 2   3       axis        bronet mini 1.5gb 7 hari
# 3   4  telkomsel  telkomsel data flash 1gb, 30hr
# 4   5       axis          bronet mini 2gb 7 hari
#
#                                          Description  Normal Price  Price  \
# 0  kuota utama 500mb + kuota area hingga 3.5gb + ...         12000  11200
# 1  kuota utama 1gb + kuota area hingga 6gb + yout...         15000  14000
# 2  kuota internet 1.5gb berlaku di semua jaringan...         14850  13973
# 3                kuota utama 1gb, masa aktif 30 hari         24280  23550
# 4  kuota internet 2gb berlaku di semua jaringan 2...         18849  16357
#
#    Discount
# 0       800
# 1      1000
# 2       877
# 3       730
# 4      2492

# %%
name = []
kuota = []
durasi = []

# %%
x = 0
for i in range(len(df_data['Name'])):
  data = df_data['Name'][i].replace(',','')
  data = data.replace(' gb','gb')
  data = data.replace(' mb','mb')
  data = data.replace(' hari','hr')
  data = data.replace('hari','hr')
  data = data.replace('/',' ')
  split_data = data.split()
  found = 0
  for j in range(len(split_data)):
    if 'gb' in split_data[j]:
      x+=1
      nama_paket = split_data[:j]
      listToStr = ' '.join(str(elem) for elem in nama_paket)
      name.append(listToStr)
      kuota.append(split_data[j])
      if 'hr' in split_data[len(split_data)-1]:
        durasi.append(split_data[len(split_data)-1])
      elif 'bulan' in split_data[len(split_data)-1]:
        time = split_data[len(split_data)-2]*30
        durasi.append(time)
      else:
        durasi.append("0")
      found = 1
      break
    elif split_data[j][-2:] == 'mb':
      x+=1
      nama_paket = split_data[:j]
      listToStr = ' '.join(str(elem) for elem in nama_paket)
      name.append(listToStr)
      kuota.append(split_data[j])
      if 'hr' in split_data[len(split_data)-1]:
        durasi.append(split_data[len(split_data)-1])
      elif 'bulan' in split_data[len(split_data)-1]:
        time = split_data[len(split_data)-2]*30
        durasi.append(time)
      else:
        durasi.append('0')
      found = 1
      break

  if found == 0:
    kuota.append('')
    if 'hr' in split_data[len(split_data)-1]:
      nama_paket = split_data[:len(split_data)-1]
      listToStr = ' '.join(str(elem) for elem in nama_paket)
      name.append(listToStr)
      durasi.append(split_data[len(split_data)-1])
    elif 'bulan' in split_data[len(split_data)-1]:
      nama_paket = split_data[:len(split_data)-1]
      listToStr = ' '.join(str(elem) for elem in nama_paket)
      name.append(listToStr)
      time = split_data[len(split_data)-2]*30
      durasi.append(time)
    else:
      name.append(data)
      durasi.append('0')
    x+=1
print(x)
# Out:
# 272

# %%
df_data[20:30]
# Out:
#     No   Operator                                               Name  \
# 20  21    indosat                           freedom u 45gb / 30 hari
# 21  22    indosat  freedom internet 44gb / 30 hari + bonus kuota ...
# 22  23         xl  xtra combo flex ultra 35gb + kuota area hingga...
# 23  24         xl  xtra combo flex supreme 48gb + kuota area hing...
# 24  25         xl                              xtra edukasi 2gb, 1hr
# 25  26         xl                              xtra edukasi 5gb, 3hr
# 26  27       axis         bronet 24 jam 1gb 1 hr + bonus lokal kuota
# 27  28         xl                                paket blue 1gb, 2hr
# 28  29         xl                              xl pure 500mb 30 hari
# 29  30  telkomsel                       paket bicara telkomsel 5.000
#
#                                           Description  Normal Price   Price  \
# 20   kuota utama 10gb + kuota youtube, netflix, i...        105500  101650
# ...

# %%
df_data['Kuota'] = kuota
df_data['Durasi'] = durasi
df_data['Name'] = name

# %%
df_data[1:10]
# Out:
#    No   Operator                        Name  \
# 1   2         xl         xtra hotrod special
# 2   3       axis                 bronet mini
# 3   4  telkomsel        telkomsel data flash
# 4   5       axis                 bronet mini
# 5   6         xl         xtra hotrod special
# 6   7       axis            aigo bronet mini
# 7   8       axis  paket internet axis bronet
# 8   9       axis                 bronet mini
# 9  10       axis                 bronet mini
#
#                                          Description  Normal Price  Price  \
# 1  kuota utama 1gb + kuota area hingga 6gb + yout...         15000  14000
# 2  kuota internet 1.5gb berlaku di semua jaringan...         14850  13973
# 3                kuota utama 1gb, masa aktif 30 hari         24280  23550
# 4  kuota internet 2gb berlaku di semua jaringan 2...         18849  16357
# 5  kuota utama 1.5gb + kuota area hingga 8.5gb + ...         20000  18725
# ...

# %%
# cols = list(df_data.columns)
# df = df_data[cols[0:3] + cols[6:8] + cols[3:6]]
# df.head(100)

# gak tak run
# Out:
#      No   Operator                            Name  Discount  Kuota  \
# 0     1         xl             xtra hotrod special       800    2gb
# 1     2         xl             xtra hotrod special      1000    3gb
# 2     3       axis                     bronet mini       877  1.5gb
# 3     4  telkomsel            telkomsel data flash       730    1gb
# 4     5       axis                     bronet mini      2492    2gb
# ..  ...        ...                             ...       ...    ...
# 95   96    indosat                freedom internet         0   42gb
# 96   97    indosat                   freedom combo         0   40gb
# 97   98    indosat                   freedom combo         0   40gb
# 98   99    indosat        freedom internet sensasi         0   50gb
# 99  100  telkomsel  paket bicara telkomsel 100.000         0
#
#                                           Description  Normal Price   Price
# 0   kuota utama 500mb + kuota area hingga 3.5gb + ...         12000   11200
# ...

# %%
df_data['Durasi'] = df_data['Durasi'].map(lambda x: x.replace('hr',''))

# %%
df = df_data
df.head(5)
# Out:
#    No   Operator                  Name  \
# 0   1         xl   xtra hotrod special
# 1   2         xl   xtra hotrod special
# 2   3       axis           bronet mini
# 3   4  telkomsel  telkomsel data flash
# 4   5       axis           bronet mini
#
#                                          Description  Normal Price  Price  \
# 0  kuota utama 500mb + kuota area hingga 3.5gb + ...         12000  11200
# 1  kuota utama 1gb + kuota area hingga 6gb + yout...         15000  14000
# 2  kuota internet 1.5gb berlaku di semua jaringan...         14850  13973
# 3                kuota utama 1gb, masa aktif 30 hari         24280  23550
# 4  kuota internet 2gb berlaku di semua jaringan 2...         18849  16357
#
#    Discount  Kuota Durasi
# 0       800    2gb      7
# 1      1000    3gb      7
# 2       877  1.5gb      7
# 3       730    1gb     30
# 4      2492    2gb      7

# %%
# df['Kuota'] = df['Kuota'].map(lambda x: x.replace('gb',''))

# %%
# df['Kuota'] = df['Kuota'].map(lambda x: x.replace('mb',''))

# %%
df.head(10)
# Out:
#    No   Operator                        Name  \
# 0   1         xl         xtra hotrod special
# 1   2         xl         xtra hotrod special
# 2   3       axis                 bronet mini
# 3   4  telkomsel        telkomsel data flash
# 4   5       axis                 bronet mini
# 5   6         xl         xtra hotrod special
# 6   7       axis            aigo bronet mini
# 7   8       axis  paket internet axis bronet
# 8   9       axis                 bronet mini
# 9  10       axis                 bronet mini
#
#                                          Description  Normal Price  Price  \
# 0  kuota utama 500mb + kuota area hingga 3.5gb + ...         12000  11200
# 1  kuota utama 1gb + kuota area hingga 6gb + yout...         15000  14000
# 2  kuota internet 1.5gb berlaku di semua jaringan...         14850  13973
# 3                kuota utama 1gb, masa aktif 30 hari         24280  23550
# 4  kuota internet 2gb berlaku di semua jaringan 2...         18849  16357
# ...

# %%
df['Kuota'] = df['Kuota'].astype('string')
df['Operator'] = df['Operator'].astype('string')
df['Name'] = df['Name'].astype('string')
df['Description'] = df['Description'].astype('string')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No            272 non-null    int64
#  1   Operator      272 non-null    string
#  2   Name          272 non-null    string
#  3   Description   272 non-null    string
#  4   Normal Price  272 non-null    int64
#  5   Price         272 non-null    int64
#  6   Discount      272 non-null    int64
#  7   Kuota         272 non-null    string
#  8   Durasi        272 non-null    object
# dtypes: int64(4), object(1), string(4)
# memory usage: 19.2+ KB
# None

# %%
df
# Out:
#       No   Operator                              Name  \
# 0      1         xl               xtra hotrod special
# 1      2         xl               xtra hotrod special
# 2      3       axis                       bronet mini
# 3      4  telkomsel              telkomsel data flash
# 4      5       axis                       bronet mini
# ..   ...        ...                               ...
# 267  268    indosat                     freedom combo
# 268  269         xl          paket internet xl hotrod
# 269  270  telkomsel  paket internet bulanan omg! 210k
# 270  271         xl          paket internet xl hotrod
# 271  272         xl                       paket akrab
#
#                                            Description  Normal Price   Price  \
# 0    kuota utama 500mb + kuota area hingga 3.5gb + ...         12000   11200
# 1    kuota utama 1gb + kuota area hingga 6gb + yout...         15000   14000
# 2    kuota internet 1.5gb berlaku di semua jaringan...         14850   13973
# ...

# %%
df.loc[df['Durasi'] == '', 'Durasi'] = 0.0


df['Durasi']=df['Durasi'].astype(float)

# %%
df.dtypes
# Out:
# No                int64
# Operator         string
# Name             string
# Description      string
# Normal Price      int64
# Price             int64
# Discount          int64
# Kuota            string
# Durasi          float64
# dtype: object

# %%
df.head(5)
# Out:
#    No   Operator                  Name  \
# 0   1         xl   xtra hotrod special
# 1   2         xl   xtra hotrod special
# 2   3       axis           bronet mini
# 3   4  telkomsel  telkomsel data flash
# 4   5       axis           bronet mini
#
#                                          Description  Normal Price  Price  \
# 0  kuota utama 500mb + kuota area hingga 3.5gb + ...         12000  11200
# 1  kuota utama 1gb + kuota area hingga 6gb + yout...         15000  14000
# 2  kuota internet 1.5gb berlaku di semua jaringan...         14850  13973
# 3                kuota utama 1gb, masa aktif 30 hari         24280  23550
# 4  kuota internet 2gb berlaku di semua jaringan 2...         18849  16357
#
#    Discount  Kuota  Durasi
# 0       800    2gb     7.0
# 1      1000    3gb     7.0
# 2       877  1.5gb     7.0
# 3       730    1gb    30.0
# 4      2492    2gb     7.0

# %%
df.to_csv(r'PD_2.csv', index=False)
